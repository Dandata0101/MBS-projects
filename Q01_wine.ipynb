# %%
import os
import sys
import pandas as pd
import sqlite3
import my_packages.Sql_table_details

# Paths and directory
current_directory = os.getcwd()
wine = os.path.join(current_directory, "01-data/01_wine_Project", "wine.db")

# function that checks table details
my_packages.Sql_table_details.display_table_details(wine)

my_packages.Sql_table_details.sample_table(wine,'Wine',10)
# Out:
# Table: Grape
# +-----+---------+---------+---------+------------+----+
# | cid |   name  |   type  | notnull | dflt_value | pk |
# +-----+---------+---------+---------+------------+----+
# |  0  |    id   | INTEGER |    0    |    None    | 1  |
# |  1  | variety |   TEXT  |    0    |    None    | 0  |
# +-----+---------+---------+---------+------------+----+
#
# Table: Winery
# +-----+----------+---------+---------+------------+----+
# | cid |   name   |   type  | notnull | dflt_value | pk |
# +-----+----------+---------+---------+------------+----+
# |  0  |    id    | INTEGER |    0    |    None    | 1  |
# |  1  | country  |   TEXT  |    0    |    None    | 0  |
# |  2  | province |   TEXT  |    0    |    None    | 0  |
# |  3  |  winery  |   TEXT  |    0    |    None    | 0  |
# +-----+----------+---------+---------+------------+----+
#
# Table: Rater
# +-----+----------------+---------+---------+------------+----+
# | cid |      name      |   type  | notnull | dflt_value | pk |
# ...

# %%
import os
import sys
import pandas as pd

# Paths and directory
current_directory = os.getcwd()
file = os.path.join(current_directory, "01-data/01_wine_Project", "Wine_Python.xlsx")
#copy = os.path.join(current_directory, "01-data/DOW30", "Dow30_2020.xlsx")

df = pd.read_excel(file)
df.tail(50)
# Out:
#             country           land           province  \
# 114650    Argentina  South America   Mendoza Province
# 114651      Germany         Europe   Mosel-Saar-Ruwer
# 114652           US  North America         Washington
# 114653           US  North America         California
# 114654    Argentina  South America   Mendoza Province
# 114655      Austria         Europe      Südsteiermark
# 114656      Germany         Europe   Mosel-Saar-Ruwer
# 114657      Germany         Europe   Mosel-Saar-Ruwer
# 114658    Argentina  South America   Mendoza Province
# 114659           US  North America         Washington
# 114660           US  North America         Washington
# 114661        Spain         Europe          Catalonia
# 114662        Spain         Europe     Northern Spain
# 114663       France         Europe           Burgundy
# 114664    Argentina  South America   Mendoza Province
# 114665      Austria         Europe            Austria
# ...
