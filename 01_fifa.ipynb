# %% [markdown]
# ## Q1. Work on the FIFA dataset: FIFA.db
# The FIFA dataset contains seven tables: Attacking, Club, Defending, Goalkeeping, Movement Player and Skill.

# %%
import os
import sys
import pandas as pd
import sqlite3
import my_packages.Sql_table_details

# Paths and directory
current_directory = os.getcwd()
fifa = os.path.join(current_directory, "01-data/02_fifa_Project", "fifa.db")

# function that checks table details
my_packages.Sql_table_details.display_table_details(fifa)
# Out:
# Table: Club
# +-----+---------------+---------+---------+------------+----+
# | cid |      name     |   type  | notnull | dflt_value | pk |
# +-----+---------------+---------+---------+------------+----+
# |  0  |      cid      | INTEGER |    0    |    None    | 1  |
# |  1  |   club_name   |   TEXT  |    0    |    None    | 0  |
# |  2  |  league_name  |   TEXT  |    0    |    None    | 0  |
# |  3  |  league_level | INTEGER |    0    |    None    | 0  |
# |  4  | club_logo_url |   TEXT  |    0    |    None    | 0  |
# |  5  | club_flag_url |   TEXT  |    0    |    None    | 0  |
# +-----+---------------+---------+---------+------------+----+
#
# Table: Player
# +-----+--------------------------+---------+---------+------------+----+
# | cid |           name           |   type  | notnull | dflt_value | pk |
# +-----+--------------------------+---------+---------+------------+----+
# |  0  |           pid            | INTEGER |    0    |    None    | 1  |
# |  1  |        short_name        |   TEXT  |    0    |    None    | 0  |
# |  2  |        long_name         |   TEXT  |    0    |    None    | 0  |
# |  3  |           age            | INTEGER |    0    |    None    | 0  |
# |  4  |     player_positions     |   TEXT  |    0    |    None    | 0  |
# |  5  |         overall          | INTEGER |    0    |    None    | 0  |
# |  6  |        potential         | INTEGER |    0    |    None    | 0  |
# |  7  |        value_eur         |   REAL  |    0    |    None    | 0  |
# |  8  |         wage_eur         |   REAL  |    0    |    None    | 0  |
# |  9  |    release_clause_eur    |   REAL  |    0    |    None    | 0  |
# |  10 |        height_cm         | INTEGER |    0    |    None    | 0  |
# |  11 |        weight_kg         | INTEGER |    0    |    None    | 0  |
# |  12 |       club_team_id       |   REAL  |    0    |    None    | 0  |
# |  13 |      club_position       |   TEXT  |    0    |    None    | 0  |
# |  14 |    club_jersey_number    |   REAL  |    0    |    None    | 0  |
# |  15 |      nationality_id      | INTEGER |    0    |    None    | 0  |
# |  16 |      nation_team_id      |   REAL  |    0    |    None    | 0  |
# |  17 |     nation_position      |   TEXT  |    0    |    None    | 0  |
# |  18 |   nation_jersey_number   |   REAL  |    0    |    None    | 0  |
# |  19 |      preferred_foot      |   TEXT  |    0    |    None    | 0  |
# |  20 |        weak_foot         | INTEGER |    0    |    None    | 0  |
# |  21 |       skill_moves        | INTEGER |    0    |    None    | 0  |
# |  22 | international_reputation | INTEGER |    0    |    None    | 0  |
# |  23 |        work_rate         |   TEXT  |    0    |    None    | 0  |
# |  24 |      player_traits       |   TEXT  |    0    |    None    | 0  |
# |  25 |           pace           |   REAL  |    0    |    None    | 0  |
# |  26 |         shooting         |   REAL  |    0    |    None    | 0  |
# |  27 |         passing          |   REAL  |    0    |    None    | 0  |
# |  28 |        dribbling         |   REAL  |    0    |    None    | 0  |
# |  29 |        defending         |   REAL  |    0    |    None    | 0  |
# |  30 |          physic          |   REAL  |    0    |    None    | 0  |
# +-----+--------------------------+---------+---------+------------+----+
#
# Table: Movement
# +-----+--------------+---------+---------+------------+----+
# | cid |     name     |   type  | notnull | dflt_value | pk |
# +-----+--------------+---------+---------+------------+----+
# |  0  |     mid      | INTEGER |    0    |    None    | 1  |
# |  1  | acceleration | INTEGER |    0    |    None    | 0  |
# |  2  | sprint_speed | INTEGER |    0    |    None    | 0  |
# |  3  |   agility    | INTEGER |    0    |    None    | 0  |
# |  4  |  reactions   | INTEGER |    0    |    None    | 0  |
# |  5  |   balance    | INTEGER |    0    |    None    | 0  |
# +-----+--------------+---------+---------+------------+----+
#
# Table: Defending
# +-----+-------------+---------+---------+------------+----+
# | cid |     name    |   type  | notnull | dflt_value | pk |
# +-----+-------------+---------+---------+------------+----+
# |  0  |     did     | INTEGER |    0    |    None    | 1  |
# |  1  |    diving   | INTEGER |    0    |    None    | 0  |
# |  2  |   handling  | INTEGER |    0    |    None    | 0  |
# |  3  |   kicking   | INTEGER |    0    |    None    | 0  |
# |  4  | positioning | INTEGER |    0    |    None    | 0  |
# |  5  |   reflexes  | INTEGER |    0    |    None    | 0  |
# |  6  |    speed    |   REAL  |    0    |    None    | 0  |
# +-----+-------------+---------+---------+------------+----+
#
# Table: Skill
# +-----+--------------+---------+---------+------------+----+
# | cid |     name     |   type  | notnull | dflt_value | pk |
# +-----+--------------+---------+---------+------------+----+
# |  0  |     sid      | INTEGER |    0    |    None    | 1  |
# |  1  |  dribbling   | INTEGER |    0    |    None    | 0  |
# |  2  |    curve     | INTEGER |    0    |    None    | 0  |
# |  3  | fk_accuracy  | INTEGER |    0    |    None    | 0  |
# |  4  | long_passing | INTEGER |    0    |    None    | 0  |
# |  5  | ball_control | INTEGER |    0    |    None    | 0  |
# +-----+--------------+---------+---------+------------+----+
#
# Table: Goalkeeping
# +-----+-------------+---------+---------+------------+----+
# | cid |     name    |   type  | notnull | dflt_value | pk |
# +-----+-------------+---------+---------+------------+----+
# |  0  |     gid     | INTEGER |    0    |    None    | 1  |
# |  1  |    diving   | INTEGER |    0    |    None    | 0  |
# |  2  |   handling  | INTEGER |    0    |    None    | 0  |
# |  3  |   kicking   | INTEGER |    0    |    None    | 0  |
# |  4  | positioning | INTEGER |    0    |    None    | 0  |
# |  5  |   reflexes  | INTEGER |    0    |    None    | 0  |
# |  6  |    speed    |   REAL  |    0    |    None    | 0  |
# +-----+-------------+---------+---------+------------+----+
#
# Table: Attacking
# +-----+------------------+---------+---------+------------+----+
# | cid |       name       |   type  | notnull | dflt_value | pk |
# +-----+------------------+---------+---------+------------+----+
# |  0  |       aid        | INTEGER |    0    |    None    | 1  |
# |  1  |     crossing     | INTEGER |    0    |    None    | 0  |
# |  2  | heading_accuracy | INTEGER |    0    |    None    | 0  |
# |  3  |    finishing     | INTEGER |    0    |    None    | 0  |
# |  4  |  short_passing   | INTEGER |    0    |    None    | 0  |
# |  5  |     volleys      | INTEGER |    0    |    None    | 0  |
# +-----+------------------+---------+---------+------------+----+
