# %%
import os
import sys
import pandas as pd
import sqlite3
import my_packages.Sql_table_details 

# Paths and directory
current_directory = os.getcwd()
fifa = os.path.join(current_directory, "01-data/02_fifa_Project", "FIFA.db")

# function that checks table details
my_packages.Sql_table_details.display_table_details(fifa)

my_packages.Sql_table_details.sample_table(fifa,'Club',10)
# Out:
# Table: Club
#    cid           name     type  notnull dflt_value  pk
# 0    0            cid  INTEGER        0       None   1
# 1    1      club_name     TEXT        0       None   0
# 2    2    league_name     TEXT        0       None   0
# 3    3   league_level  INTEGER        0       None   0
# 4    4  club_logo_url     TEXT        0       None   0
# 5    5  club_flag_url     TEXT        0       None   0
#
# Table: Player
#     cid                      name     type  notnull dflt_value  pk
# 0     0                       pid  INTEGER        0       None   1
# 1     1                short_name     TEXT        0       None   0
# 2     2                 long_name     TEXT        0       None   0
# 3     3                       age  INTEGER        0       None   0
# 4     4          player_positions     TEXT        0       None   0
# 5     5                   overall  INTEGER        0       None   0
# 6     6                 potential  INTEGER        0       None   0
# 7     7                 value_eur     REAL        0       None   0
# 8     8                  wage_eur     REAL        0       None   0
# 9     9        release_clause_eur     REAL        0       None   0
# 10   10                 height_cm  INTEGER        0       None   0
# 11   11                 weight_kg  INTEGER        0       None   0
# 12   12              club_team_id     REAL        0       None   0
# 13   13             club_position     TEXT        0       None   0
# 14   14        club_jersey_number     REAL        0       None   0
# 15   15            nationality_id  INTEGER        0       None   0
# 16   16            nation_team_id     REAL        0       None   0
# 17   17           nation_position     TEXT        0       None   0
# 18   18      nation_jersey_number     REAL        0       None   0
# 19   19            preferred_foot     TEXT        0       None   0
# 20   20                 weak_foot  INTEGER        0       None   0
# 21   21               skill_moves  INTEGER        0       None   0
# 22   22  international_reputation  INTEGER        0       None   0
# 23   23                 work_rate     TEXT        0       None   0
# 24   24             player_traits     TEXT        0       None   0
# 25   25                      pace     REAL        0       None   0
# 26   26                  shooting     REAL        0       None   0
# 27   27                   passing     REAL        0       None   0
# 28   28                 dribbling     REAL        0       None   0
# 29   29                 defending     REAL        0       None   0
# 30   30                    physic     REAL        0       None   0
#
# Table: Movement
#    cid          name     type  notnull dflt_value  pk
# 0    0           mid  INTEGER        0       None   1
# 1    1  acceleration  INTEGER        0       None   0
# 2    2  sprint_speed  INTEGER        0       None   0
# 3    3       agility  INTEGER        0       None   0
# 4    4     reactions  INTEGER        0       None   0
# 5    5       balance  INTEGER        0       None   0
#
# Table: Defending
#    cid         name     type  notnull dflt_value  pk
# 0    0          did  INTEGER        0       None   1
# 1    1       diving  INTEGER        0       None   0
# 2    2     handling  INTEGER        0       None   0
# 3    3      kicking  INTEGER        0       None   0
# 4    4  positioning  INTEGER        0       None   0
# 5    5     reflexes  INTEGER        0       None   0
# 6    6        speed     REAL        0       None   0
#
# Table: Skill
#    cid          name     type  notnull dflt_value  pk
# 0    0           sid  INTEGER        0       None   1
# 1    1     dribbling  INTEGER        0       None   0
# 2    2         curve  INTEGER        0       None   0
# 3    3   fk_accuracy  INTEGER        0       None   0
# 4    4  long_passing  INTEGER        0       None   0
# 5    5  ball_control  INTEGER        0       None   0
#
# Table: Goalkeeping
#    cid         name     type  notnull dflt_value  pk
# 0    0          gid  INTEGER        0       None   1
# 1    1       diving  INTEGER        0       None   0
# 2    2     handling  INTEGER        0       None   0
# 3    3      kicking  INTEGER        0       None   0
# 4    4  positioning  INTEGER        0       None   0
# 5    5     reflexes  INTEGER        0       None   0
# 6    6        speed     REAL        0       None   0
#
# Table: Attacking
#    cid              name     type  notnull dflt_value  pk
# 0    0               aid  INTEGER        0       None   1
# 1    1          crossing  INTEGER        0       None   0
# 2    2  heading_accuracy  INTEGER        0       None   0
# 3    3         finishing  INTEGER        0       None   0
# 4    4     short_passing  INTEGER        0       None   0
# 5    5           volleys  INTEGER        0       None   0
#    cid          club_name                  league_name  league_level  \
# 0    1            Arsenal       English Premier League             1
# 1    2        Aston Villa       English Premier League             1
# 2    3   Blackburn Rovers  English League Championship             2
# 3    4   Bolton Wanderers           English League One             3
# 4    5            Chelsea       English Premier League             1
# 5    7            Everton       English Premier League             1
# 6    8       Leeds United       English Premier League             1
# 7    9          Liverpool       English Premier League             1
# 8   10    Manchester City       English Premier League             1
# 9   11  Manchester United       English Premier League             1
#
#                             club_logo_url  \
# 0   https://cdn.sofifa.net/teams/1/60.png
# 1   https://cdn.sofifa.net/teams/2/60.png
# 2   https://cdn.sofifa.net/teams/3/60.png
# 3   https://cdn.sofifa.net/teams/4/60.png
# 4   https://cdn.sofifa.net/teams/5/60.png
# 5   https://cdn.sofifa.net/teams/7/60.png
# 6   https://cdn.sofifa.net/teams/8/60.png
# 7   https://cdn.sofifa.net/teams/9/60.png
# 8  https://cdn.sofifa.net/teams/10/60.png
# 9  https://cdn.sofifa.net/teams/11/60.png
#
#                              club_flag_url
# 0  https://cdn.sofifa.net/flags/gb-eng.png
# 1  https://cdn.sofifa.net/flags/gb-eng.png
# 2  https://cdn.sofifa.net/flags/gb-eng.png
# 3  https://cdn.sofifa.net/flags/gb-eng.png
# 4  https://cdn.sofifa.net/flags/gb-eng.png
# 5  https://cdn.sofifa.net/flags/gb-eng.png
# 6  https://cdn.sofifa.net/flags/gb-eng.png
# 7  https://cdn.sofifa.net/flags/gb-eng.png
# 8  https://cdn.sofifa.net/flags/gb-eng.png
# 9  https://cdn.sofifa.net/flags/gb-eng.png
